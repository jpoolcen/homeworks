# %% [markdown]
# ## Homework 3 Quadratic Functions Form
#
# Visualization of function and gradient of its.
#
# $f(x_1,x_2,x_3) = 10x^2_1 -x_1x_2 -5x_1x_3 +5x_1+10x_2^2 -11x_2x_3 -2x_2 -5x_3x_1 - 11x_3x_2 -4x_2+6x_3+9$

# %%
## Load libraries
import numpy as np
#from modules.myfuncangles='xy', scale_units='xy', scale=1tions import fx
from modules.myfunctions import grad_fx
from modules.myfunctions import plot_function_and_gradient
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-q9cwz_bs because the default path (/teamspace/studios/this_studio/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
# Crear una cuadrícula de puntos
# Fijar x3 a un valor constante, por ejemplo 0, para visualizar la función en 2D y su gradiente
x3_fixed = 0

# Rango de valores para x1 y x2
x1_range = (-2, 2)
x2_range = (-2, 2)

# Llamar a la función de visualización
plot_function_and_gradient(x1_range, x2_range, x3_fixed, num_points=20)
